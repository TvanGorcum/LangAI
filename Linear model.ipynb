# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.linear_model import SGDClassifier
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_predict
import numpy as np
from sklearn.linear_model import LogisticRegression

# %%
df = pd.read_csv("Finalized_data.csv")

# %%
df.head()
# Out:
#   auhtor_ID                                               post nationality  \
# 0  t2_qxjm2  UsA are really great at shedding the worst pos...     Germany
# 1  t2_qxjm2  and they always have been. They invaded severa...     Germany
# 2  t2_qxjm2  Cooperation lol Russia has absolutely nothing ...     Germany
# 3  t2_qxjm2  is power. I'm flabbergasted to see Stan Marsh ...     Germany
# 4  t2_qxjm2  for cutting all ties to Russia indefinitely. U...     Germany
#
#   language_family     sub_family
# 0        Germanic  West Germanic
# 1        Germanic  West Germanic
# 2        Germanic  West Germanic
# 3        Germanic  West Germanic
# 4        Germanic  West Germanic

# %%
df_copy = df.dropna()
df_copy = df_copy.astype({'nationality' : 'category',
                         'language_family' : 'category',
                         'sub_family' : 'category'})
df_copy.head()
# Out:
#   auhtor_ID                                               post nationality  \
# 0  t2_qxjm2  UsA are really great at shedding the worst pos...     Germany
# 1  t2_qxjm2  and they always have been. They invaded severa...     Germany
# 2  t2_qxjm2  Cooperation lol Russia has absolutely nothing ...     Germany
# 3  t2_qxjm2  is power. I'm flabbergasted to see Stan Marsh ...     Germany
# 4  t2_qxjm2  for cutting all ties to Russia indefinitely. U...     Germany
#
#   language_family     sub_family
# 0        Germanic  West Germanic
# 1        Germanic  West Germanic
# 2        Germanic  West Germanic
# 3        Germanic  West Germanic
# 4        Germanic  West Germanic

# %%
# Separate data into features (X) and labels (y)
X = df_copy['post']
y = df_copy['nationality']

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

# Convert text data to TF-IDF features
vectorizer = TfidfVectorizer()
X_train_tfidf = vectorizer.fit_transform(X_train)
X_test_tfidf = vectorizer.transform(X_test)

# %%
logreg_model = LogisticRegression(max_iter=1000)  # You can adjust max_iter based on your data probably 1000

# Fit the model on the training data
logreg_model.fit(X_train_tfidf, y_train)

# Make predictions on the test data
y_pred = logreg_model.predict(X_test_tfidf)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.2f}")

# Print classification report for detailed metrics
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.66
# Classification Report:
#                   precision    recall  f1-score   support
#
#         Austria       0.77      0.09      0.16       310
#          Brazil       0.00      0.00      0.00        12
#          Canada       0.87      0.06      0.11       579
#           Chili       0.00      0.00      0.00         4
#         Denmark       0.90      0.26      0.41       491
#          France       0.75      0.52      0.62       367
#         Germany       0.49      0.93      0.64      2072
#         Ireland       0.49      0.37      0.42       317
#           Italy       0.87      0.56      0.68       720
#          Norway       0.68      0.51      0.58       256
#        Portugal       0.88      0.38      0.53       298
#         Romania       0.86      0.41      0.56       397
#           Spain       0.60      0.45      0.52       169
#          Sweden       0.71      0.42      0.53       654
# The Netherlands       0.77      0.76      0.77      1255
#             USA       0.69      0.75      0.71      1996
#  United Kingdom       0.78      0.93      0.85      1874
#
#        accuracy                           0.66     11771
#       macro avg       0.65      0.44      0.48     11771
#    weighted avg       0.71      0.66      0.63     11771
# C:\Users\20212189\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\20212189\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\20212189\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Separate data into features (X) and labels (y)
X = df_copy['post']
y = df_copy['language_family']

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

# Convert text data to TF-IDF features
vectorizer = TfidfVectorizer()
X_train_tfidf = vectorizer.fit_transform(X_train)
X_test_tfidf = vectorizer.transform(X_test)

logreg_model = LogisticRegression(max_iter=1000)  # You can adjust max_iter based on your data probably 1000

# Fit the model on the training data
logreg_model.fit(X_train_tfidf, y_train)

# Make predictions on the test data
y_pred = logreg_model.predict(X_test_tfidf)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.2f}")

# Print classification report for detailed metrics
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.84
# Classification Report:
#                precision    recall  f1-score   support
#
#     Germanic       0.78      0.93      0.85      5038
#       Native       0.92      0.83      0.87      4766
#      Romance       0.89      0.63      0.74      1967
#
#     accuracy                           0.84     11771
#    macro avg       0.86      0.80      0.82     11771
# weighted avg       0.85      0.84      0.84     11771

# %%
# Separate data into features (X) and labels (y)
X = df_copy['post']
y = df_copy['sub_family']

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

# Convert text data to TF-IDF features
vectorizer = TfidfVectorizer()

X_train_tfidf = vectorizer.fit_transform(X_train)
X_test_tfidf = vectorizer.transform(X_test)

logreg_model = LogisticRegression(max_iter=1000)  # You can adjust max_iter based on your data probably 1000

# Fit the model on the training data
logreg_model.fit(X_train_tfidf, y_train)

# Make predictions on the test data
y_pred = logreg_model.predict(X_test_tfidf)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.2f}")

# Print classification report for detailed metrics
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.79
# Classification Report:
#                         precision    recall  f1-score   support
#
#       Eastern Romance       0.93      0.32      0.48       397
# Italo-Western Romance       0.77      0.66      0.71      1570
#                Native       0.87      0.88      0.88      4766
#        North Germanic       0.78      0.48      0.60      1401
#         West Germanic       0.72      0.91      0.80      3637
#
#              accuracy                           0.79     11771
#             macro avg       0.81      0.65      0.69     11771
#          weighted avg       0.80      0.79      0.78     11771
